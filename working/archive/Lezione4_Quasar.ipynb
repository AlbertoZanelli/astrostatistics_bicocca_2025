# %%
from astroML.datasets import get_data_home
print(get_data_home())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from astroML.datasets import get_data_home
#       2 print(get_data_home())
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astroML/datasets/__init__.py:14
#      12 from .sdss_corrected_spectra import fetch_sdss_corrected_spectra
#      13 from .nasa_atlas import fetch_nasa_atlas
# ---> 14 from .sdss_sspp import fetch_sdss_sspp
#      15 from .sdss_specgals import fetch_sdss_specgals, fetch_great_wall
#      16 from .imaging_sample import fetch_imaging_sample
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astroML/datasets/sdss_sspp.py:4
#       1 import os
#       3 import numpy as np
# ----> 4 from astropy.table import Table
#       6 from . import get_data_home
#       9 DATA_URL = ("https://github.com/astroML/astroML-data/raw/main/datasets/"
#      10             "SDSSssppDR9_rerun122.fit.gz")
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/table/__init__.py:6
#       3 import astropy.config as _config
#       4 from astropy.utils.compat import optional_deps
# ----> 6 from .column import Column, ColumnInfo, MaskedColumn, StringTruncateWarning
#       8 __all__ = [
#       9     "BST",
#      10     "Column",
#    (...)     43     "vstack",
#      44 ]
#      47 class Conf(_config.ConfigNamespace):
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/table/column.py:11
#       8 import numpy as np
#       9 from numpy import ma
# ---> 11 from astropy.units import Quantity, StructuredUnit, Unit
#      12 from astropy.utils.compat import COPY_IF_NEEDED, NUMPY_LT_2_0
#      13 from astropy.utils.console import color_print
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/__init__.py:13
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       3 """
#       4 This subpackage contains classes and functions for defining and converting
#       5 between different physical units, as well as the units themselves.
#    (...)     10 code under a BSD license.
#      11 """
# ---> 13 from . import (
#      14     astrophys,
#      15     cgs,
#      16     core,
#      17     decorators,
#      18     errors,
#      19     imperial,
#      20     misc,
#      21     photometric,
#      22     physical,
#      23     quantity,
#      24     required_by_vounit,
#      25     si,
#      26     structured,
#      27 )
#      28 from .astrophys import *
#      29 from .cgs import *
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/astrophys.py:12
#       7 # avoid ruff complaints about undefined names defined by def_unit
#       8 # ruff: noqa: F821
#      10 import numpy as np
# ---> 12 from astropy.constants import si as _si
#      14 from . import si
#      15 from .core import UnitBase, def_unit, set_enabled_units
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/constants/__init__.py:27
#      23 from astropy import units
#      25 del units
# ---> 27 from . import cgs, si
#      28 from . import utils as _utils
#      29 from .config import codata, iaudata
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/constants/cgs.py:7
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       2 """
#       3 Astronomical and physics constants in cgs units.  See :mod:`astropy.constants`
#       4 for a complete listing of constants defined in Astropy.
#       5 """
# ----> 7 from .config import codata, iaudata
#       8 from .constant import Constant
#      10 for _nm, _c in (*sorted(vars(codata).items()), *sorted(vars(iaudata).items())):
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/constants/config.py:15
#      12 phys_version = astropy.physical_constants.get()
#      13 astro_version = astropy.astronomical_constants.get()
# ---> 15 codata = importlib.import_module(".constants." + phys_version, "astropy")
#      16 iaudata = importlib.import_module(".constants." + astro_version, "astropy")
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/constants/codata2018.py:9
#       2 """
#       3 Astronomical and physics constants in SI units.  See :mod:`astropy.constants`
#       4 for a complete listing of constants defined in Astropy.
#       5 """
#       7 import math
# ----> 9 from .constant import Constant, EMConstant
#      11 # PHYSICAL CONSTANTS
#      12 # https://en.wikipedia.org/wiki/2019_redefinition_of_SI_base_units
#      15 class CODATA2018(Constant):
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/constants/constant.py:11
#       9 from astropy.units.core import Unit
#      10 from astropy.units.errors import UnitsError
# ---> 11 from astropy.units.quantity import Quantity
#      12 from astropy.utils import lazyproperty
#      13 from astropy.utils.exceptions import AstropyUserWarning
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/quantity.py:28
#      26 from .errors import UnitConversionError, UnitsError, UnitTypeError
#      27 from .format import Base, Latex
# ---> 28 from .quantity_helper import can_have_arbitrary_unit, check_output, converters_and_unit
#      29 from .quantity_helper.function_helpers import (
#      30     DISPATCHED_FUNCTIONS,
#      31     FUNCTION_HELPERS,
#    (...)     34     UNSUPPORTED_FUNCTIONS,
#      35 )
#      36 from .structured import StructuredUnit, _structured_unit_like_dtype
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/quantity_helper/__init__.py:16
#       8 from .converters import *
#      10 # isort: split
#      11 # By importing helpers, all the unit conversion functions needed for
#      12 # numpy ufuncs and functions are defined.
#      13 # For scipy.special and erfa, importing the helper modules ensures
#      14 # the definitions are added as modules to UFUNC_HELPERS, to be loaded
#      15 # on demand.
# ---> 16 from . import erfa, function_helpers, helpers, scipy_special
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/quantity_helper/function_helpers.py:1246
#    1242     (ar1, ar2), unit = _quantities2arrays(element, test_elements)
#    1243     return (ar1, ar2) + args, kwargs, None, None
# -> 1246 @function_helper  # np.in1d deprecated in not NUMPY_LT_2_0.
#    1247 def in1d(ar1, ar2, *args, **kwargs):
#    1248     # This tests whether ar1 is in ar2, so we should change the unit of
#    1249     # ar1 to that of ar2.
#    1250     (ar2, ar1), unit = _quantities2arrays(ar2, ar1)
#    1251     return (ar1, ar2) + args, kwargs, None, None
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/astropy/units/quantity_helper/function_helpers.py:205, in FunctionAssigner.__call__(self, f, helps, module)
#     203 if f is not None:
#     204     if helps is None:
# --> 205         helps = getattr(module, f.__name__)
#     206     if not np.iterable(helps):
#     207         helps = (helps,)
#
# File /opt/anaconda3/envs/pyrootAlbi/lib/python3.12/site-packages/numpy/__init__.py:792, in __getattr__(attr)
#     789     import numpy.char as char
#     790     return char.chararray
# --> 792 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'in1d'

# %%
from astroML.datasets import fetch_dr7_quasar
from load_quasar_data import load_dr7_quasar
import numpy as np
import matplotlib.pyplot as plt

# Fetch the quasar data
data = load_dr7_quasar()

# select the first 10000 points
data = data[:10000]
z = data['redshift']

# Generate 10000 random numbers between z.min() and z.max()
random_numbers = np.random.uniform(z.min(), z.max(), 1000000)
# Calculate the histogram
hist, bin_edges = np.histogram(z, bins=100, density=True)

#for i in 
# Find the bin index for each random number
bin_indices = np.digitize(random_numbers, bin_edges) - 1

# Get the histogram value for each random number
hist_values = hist[bin_indices]
accepted = []

for i in range(len(hist_values)):
    if np.random.uniform(0,1) < hist_values[i]:
        # Accept the random number
        accepted.append(random_numbers[i])



# Plot the histogram
plt.hist(z, bins=100, density=False, edgecolor='black')
plt.xlabel('Redshift')
plt.ylabel('Number of Quasars')
plt.title('Distribution of Quasar Redshifts')
plt.show()

# Plot the histogram
plt.hist(accepted, bins=100, density=False, edgecolor='black')
plt.xlabel('Redshift')
plt.ylabel('Number of Quasars')
plt.title('Distribution of Quasar Redshifts')
plt.show()

print(len(hist))
print(len(bin_edges))
# Out:
# 100
# 101

# %%
from scipy.interpolate import interp1d

# Calcolare la CDF del vettore z
sorted_z = np.sort(z)
cdf = np.arange(1, len(sorted_z) + 1) / len(sorted_z)

# Creare una funzione di interpolazione per la CDF inversa
inverse_cdf = interp1d(cdf, sorted_z, bounds_error=False, fill_value=(sorted_z[0], sorted_z[-1]))

# Generare nuovi dati utilizzando la CDF inversa
new_data_size = 1000000  # Numero di nuovi dati da generare
random_cdf_values = np.random.uniform(0, 1, new_data_size)
new_z = inverse_cdf(random_cdf_values)

# Aggiungere i nuovi dati al vettore z esistente
augmented_z = np.concatenate([z, new_z])

# Visualizzare i dati aumentati
plt.hist(augmented_z, bins=100, density=False, edgecolor='black')
plt.xlabel('Redshift')
plt.ylabel('Number of Quasars')
plt.title('Distribution of Augmented Quasar Redshifts')
plt.show()
